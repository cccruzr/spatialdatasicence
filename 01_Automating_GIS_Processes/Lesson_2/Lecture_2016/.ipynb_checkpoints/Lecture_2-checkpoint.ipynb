# %% [markdown]
# # Introduction to Geopandas
# ## Reading a shapefile
#
# Spatial data can be read easily with geopandas using `gpd.from_file()` function:

# %%
# Import necessary modules
import geopandas as gpd

# Set filepath (fix path relative to yours)
fp = "Data/DAMSELFISH_distributions.shp"

# Read file using gpd.read_file()
data = gpd.read_file(fp)

# %%
#Let’s see what datatype is our ‘data’ variable
type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
print(data.shape)
data
# Out:
# (231, 25)
#                     binomial category  \
# 0         Stegastes leucorus       VU
# 1         Stegastes leucorus       VU
# 2         Stegastes leucorus       VU
# 3        Chromis intercrusma       LC
# 4        Chromis intercrusma       LC
# 5        Chromis intercrusma       LC
# 6           Stegastes beebei       VU
# 7           Stegastes beebei       VU
# 8           Stegastes beebei       VU
# 9           Stegastes beebei       VU
# 10          Stegastes beebei       VU
# 11          Stegastes beebei       VU
# 12          Stegastes beebei       VU
# 13          Stegastes beebei       VU
# 14    Stegastes rectifraenum       LC
# 15    Stegastes rectifraenum       LC
# 16    Stegastes rectifraenum       LC
# 17      Chromis punctipinnis       LC
# 18            Chromis crusma       LC
# 19            Chromis crusma       LC
# 20            Chromis crusma       LC
# 21            Chromis pembae       LC
# 22            Chromis pembae       LC
# 23            Chromis pembae       LC
# 24            Chromis pembae       LC
# 25       Stegastes redemptus       VU
# 26       Stegastes redemptus       VU
# 27    Teixeirichthys jordani       LC
# 28    Teixeirichthys jordani       LC
# 29    Teixeirichthys jordani       LC
# ..                       ...      ...
# 201  Chrysiptera flavipinnis       LC
# 202  Chrysiptera flavipinnis       LC
# 203  Chrysiptera flavipinnis       LC
# 204       Chromis atrilobata       LC
# 205       Chromis atrilobata       LC
# 206       Chromis atrilobata       LC
# 207       Chromis atrilobata       LC
# 208       Chromis atrilobata       LC
# 209       Chromis atrilobata       LC
# 210       Chromis atrilobata       LC
# 211       Chromis atrilobata       LC
# 212       Chromis atrilobata       LC
# 213  Stegastes acapulcoensis       LC
# 214  Stegastes acapulcoensis       LC
# 215  Stegastes acapulcoensis       LC
# 216  Stegastes acapulcoensis       LC
# 217  Stegastes acapulcoensis       LC
# 218  Stegastes acapulcoensis       LC
# 219  Stegastes acapulcoensis       LC
# 220  Stegastes acapulcoensis       LC
# 221  Stegastes acapulcoensis       LC
# 222     Hypsypops rubicundus       LC
# 223     Hypsypops rubicundus       LC
# 224     Hypsypops rubicundus       LC
# 225     Hypsypops rubicundus       LC
# 226          Azurina hirundo       NT
# 227          Azurina hirundo       NT
# 228          Azurina hirundo       NT
# 229          Azurina hirundo       NT
# 230          Azurina hirundo       NT
#
#                                               citation      class_name  \
# 0    International Union for Conservation of Nature...  ACTINOPTERYGII
# 1    International Union for Conservation of Nature...  ACTINOPTERYGII
# 2    International Union for Conservation of Nature...  ACTINOPTERYGII
# 3    International Union for Conservation of Nature...  ACTINOPTERYGII
# 4    International Union for Conservation of Nature...  ACTINOPTERYGII
# 5    International Union for Conservation of Nature...  ACTINOPTERYGII
# 6    International Union for Conservation of Nature...  ACTINOPTERYGII
# 7    International Union for Conservation of Nature...  ACTINOPTERYGII
# 8    International Union for Conservation of Nature...  ACTINOPTERYGII
# 9    International Union for Conservation of Nature...  ACTINOPTERYGII
# 10   International Union for Conservation of Nature...  ACTINOPTERYGII
# 11   International Union for Conservation of Nature...  ACTINOPTERYGII
# 12   International Union for Conservation of Nature...  ACTINOPTERYGII
# 13   International Union for Conservation of Nature...  ACTINOPTERYGII
# 14   International Union for Conservation of Nature...  ACTINOPTERYGII
# 15   International Union for Conservation of Nature...  ACTINOPTERYGII
# 16   International Union for Conservation of Nature...  ACTINOPTERYGII
# 17   International Union for Conservation of Nature...  ACTINOPTERYGII
# 18   International Union for Conservation of Nature...  ACTINOPTERYGII
# 19   International Union for Conservation of Nature...  ACTINOPTERYGII
# 20   International Union for Conservation of Nature...  ACTINOPTERYGII
# 21   International Union for Conservation of Nature...  ACTINOPTERYGII
# 22   International Union for Conservation of Nature...  ACTINOPTERYGII
# 23   International Union for Conservation of Nature...  ACTINOPTERYGII
# 24   International Union for Conservation of Nature...  ACTINOPTERYGII
# 25   International Union for Conservation of Nature...  ACTINOPTERYGII
# 26   International Union for Conservation of Nature...  ACTINOPTERYGII
# 27   Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
# 28   Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
# 29   Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
# ..                                                 ...             ...
# 201  International Union for Conservation of Nature...  ACTINOPTERYGII
# 202  International Union for Conservation of Nature...  ACTINOPTERYGII
# 203  International Union for Conservation of Nature...  ACTINOPTERYGII
# 204  International Union for Conservation of Nature...  ACTINOPTERYGII
# 205  International Union for Conservation of Nature...  ACTINOPTERYGII
# 206  International Union for Conservation of Nature...  ACTINOPTERYGII
# 207  International Union for Conservation of Nature...  ACTINOPTERYGII
# 208  International Union for Conservation of Nature...  ACTINOPTERYGII
# 209  International Union for Conservation of Nature...  ACTINOPTERYGII
# 210  International Union for Conservation of Nature...  ACTINOPTERYGII
# 211  International Union for Conservation of Nature...  ACTINOPTERYGII
# 212  International Union for Conservation of Nature...  ACTINOPTERYGII
# 213  International Union for Conservation of Nature...  ACTINOPTERYGII
# 214  International Union for Conservation of Nature...  ACTINOPTERYGII
# 215  International Union for Conservation of Nature...  ACTINOPTERYGII
# 216  International Union for Conservation of Nature...  ACTINOPTERYGII
# 217  International Union for Conservation of Nature...  ACTINOPTERYGII
# 218  International Union for Conservation of Nature...  ACTINOPTERYGII
# 219  International Union for Conservation of Nature...  ACTINOPTERYGII
# 220  International Union for Conservation of Nature...  ACTINOPTERYGII
# 221  International Union for Conservation of Nature...  ACTINOPTERYGII
# 222  International Union for Conservation of Nature...  ACTINOPTERYGII
# 223  International Union for Conservation of Nature...  ACTINOPTERYGII
# 224  International Union for Conservation of Nature...  ACTINOPTERYGII
# 225  International Union for Conservation of Nature...  ACTINOPTERYGII
# 226  International Union for Conservation of Nature...  ACTINOPTERYGII
# 227  International Union for Conservation of Nature...  ACTINOPTERYGII
# 228  International Union for Conservation of Nature...  ACTINOPTERYGII
# 229  International Union for Conservation of Nature...  ACTINOPTERYGII
# 230  International Union for Conservation of Nature...  ACTINOPTERYGII
#
#     compiler dist_comm     family_nam      genus_name  \
# 0       IUCN      None  POMACENTRIDAE       Stegastes
# 1       IUCN      None  POMACENTRIDAE       Stegastes
# 2       IUCN      None  POMACENTRIDAE       Stegastes
# 3       IUCN      None  POMACENTRIDAE         Chromis
# 4       IUCN      None  POMACENTRIDAE         Chromis
# 5       IUCN      None  POMACENTRIDAE         Chromis
# 6       IUCN      None  POMACENTRIDAE       Stegastes
# 7       IUCN      None  POMACENTRIDAE       Stegastes
# 8       IUCN      None  POMACENTRIDAE       Stegastes
# 9       IUCN      None  POMACENTRIDAE       Stegastes
# 10      IUCN      None  POMACENTRIDAE       Stegastes
# 11      IUCN      None  POMACENTRIDAE       Stegastes
# 12      IUCN      None  POMACENTRIDAE       Stegastes
# 13      IUCN      None  POMACENTRIDAE       Stegastes
# 14      IUCN      None  POMACENTRIDAE       Stegastes
# 15      IUCN      None  POMACENTRIDAE       Stegastes
# 16      IUCN      None  POMACENTRIDAE       Stegastes
# 17      None      None  POMACENTRIDAE         Chromis
# 18      IUCN      None  POMACENTRIDAE         Chromis
# 19      IUCN      None  POMACENTRIDAE         Chromis
# 20      IUCN      None  POMACENTRIDAE         Chromis
# 21      None      None  POMACENTRIDAE         Chromis
# 22      None      None  POMACENTRIDAE         Chromis
# 23      None      None  POMACENTRIDAE         Chromis
# 24      None      None  POMACENTRIDAE         Chromis
# 25      IUCN      None  POMACENTRIDAE       Stegastes
# 26      IUCN      None  POMACENTRIDAE       Stegastes
# 27      None      None  POMACENTRIDAE  Teixeirichthys
# 28      None      None  POMACENTRIDAE  Teixeirichthys
# 29      None      None  POMACENTRIDAE  Teixeirichthys
# ..       ...       ...            ...             ...
# 201     None      None  POMACENTRIDAE     Chrysiptera
# 202     None      None  POMACENTRIDAE     Chrysiptera
# 203     None      None  POMACENTRIDAE     Chrysiptera
# 204     IUCN      None  POMACENTRIDAE         Chromis
# 205     IUCN      None  POMACENTRIDAE         Chromis
# 206     IUCN      None  POMACENTRIDAE         Chromis
# 207     IUCN      None  POMACENTRIDAE         Chromis
# 208     IUCN      None  POMACENTRIDAE         Chromis
# 209     IUCN      None  POMACENTRIDAE         Chromis
# 210     IUCN      None  POMACENTRIDAE         Chromis
# 211     IUCN      None  POMACENTRIDAE         Chromis
# 212     IUCN      None  POMACENTRIDAE         Chromis
# 213     IUCN      None  POMACENTRIDAE       Stegastes
# 214     IUCN      None  POMACENTRIDAE       Stegastes
# 215     IUCN      None  POMACENTRIDAE       Stegastes
# 216     IUCN      None  POMACENTRIDAE       Stegastes
# 217     IUCN      None  POMACENTRIDAE       Stegastes
# 218     IUCN      None  POMACENTRIDAE       Stegastes
# 219     IUCN      None  POMACENTRIDAE       Stegastes
# 220     IUCN      None  POMACENTRIDAE       Stegastes
# 221     IUCN      None  POMACENTRIDAE       Stegastes
# 222     IUCN      None  POMACENTRIDAE       Hypsypops
# 223     IUCN      None  POMACENTRIDAE       Hypsypops
# 224     IUCN      None  POMACENTRIDAE       Hypsypops
# 225     IUCN      None  POMACENTRIDAE       Hypsypops
# 226     IUCN      None  POMACENTRIDAE         Azurina
# 227     IUCN      None  POMACENTRIDAE         Azurina
# 228     IUCN      None  POMACENTRIDAE         Azurina
# 229     IUCN      None  POMACENTRIDAE         Azurina
# 230     IUCN      None  POMACENTRIDAE         Azurina
#
#                                               geometry     id_no  \
# 0    POLYGON ((-115.6437454219999 29.71392059300007...  183963.0
# 1    POLYGON ((-105.589950704 21.89339825500002, -1...  183963.0
# 2    POLYGON ((-111.159618439 19.01535626700007, -1...  183963.0
# 3    POLYGON ((-80.86500229899997 -0.77894492099994...  183793.0
# 4    POLYGON ((-67.33922225599997 -55.6761029239999...  183793.0
# 5    POLYGON ((-74.81822204599996 -51.4608230589999...  183793.0
# 6    POLYGON ((-86.13105102199995 5.598867493000057...  183462.0
# 7    POLYGON ((-80.68215272899994 4.037426486000072...  183462.0
# 8    POLYGON ((-90.22271068899994 -0.27334342499995...  183462.0
# 9    POLYGON ((-83.93571481699996 9.296388679000074...  183462.0
# 10   POLYGON ((-79.15961456299993 9.011326790000055...  183462.0
# 11   POLYGON ((-91.09391784599995 -0.58096068999992...  183462.0
# 12   POLYGON ((-78.46049499599997 8.439051628000072...  183462.0
# 13   POLYGON ((-91.24864959699994 -0.67984747899993...  183462.0
# 14   POLYGON ((-114.129066467 31.49156189000007, -1...  183586.0
# 15   POLYGON ((-106.7327677389999 23.60688894500004...  183586.0
# 16   POLYGON ((-111.159618439 19.01535626700007, -1...  183586.0
# 17   POLYGON ((-121.799003601 36.75037002600004, -1...  154831.0
# 18   POLYGON ((-80.82860578399999 -1.22984210599997...  183240.0
# 19   POLYGON ((-67.33922225599997 -55.6761029239999...  183240.0
# 20   POLYGON ((-74.81822204599996 -51.4608230589999...  183240.0
# 21   POLYGON ((32.56497192400008 29.96966743400003,...  154856.0
# 22   POLYGON ((55.90029544000004 -3.630027441999971...  154856.0
# 23   POLYGON ((73.86925448500006 7.187452539000049,...  154856.0
# 24   POLYGON ((39.89708328200004 16.32163810700007,...  154856.0
# 25   POLYGON ((-112.128707413 25.07043759500004, -1...  183567.0
# 26   POLYGON ((-111.159618439 19.01535626700007, -1...  183567.0
# 27   POLYGON ((121.6300326400001 33.04248618400004,...  154915.0
# 28   POLYGON ((32.56219482400007 29.97488975500005,...  154915.0
# 29   POLYGON ((130.9052090560001 34.02498196400006,...  154915.0
# ..                                                 ...       ...
# 201  POLYGON ((164.5374754960001 -20.08774569199994...  154920.0
# 202  POLYGON ((151.2978177690001 -16.88691080299998...  154920.0
# 203  POLYGON ((159.58249191 -21.61306719099997, 159...  154920.0
# 204  POLYGON ((-90.09187344499998 13.72481517500006...  183653.0
# 205  POLYGON ((-113.422749196 30.12412492800007, -1...  183653.0
# 206  POLYGON ((-106.72576642 23.59774532600005, -10...  183653.0
# 207  POLYGON ((-86.13105102199995 5.598867493000057...  183653.0
# 208  POLYGON ((-111.159618439 19.01535626700007, -1...  183653.0
# 209  POLYGON ((-80.68215272899994 4.037426486000072...  183653.0
# 210  POLYGON ((-90.22271068899994 -0.27334342499995...  183653.0
# 211  POLYGON ((-91.09391784599995 -0.58096068999992...  183653.0
# 212  POLYGON ((-91.24864959699994 -0.67984747899993...  183653.0
# 213  POLYGON ((-90.09187344499998 13.72481517500006...  183431.0
# 214  POLYGON ((-106.726318976 23.59928014100007, -1...  183431.0
# 215  POLYGON ((-109.2706279609999 26.29294047400003...  183431.0
# 216  POLYGON ((-86.13105102199995 5.598867493000057...  183431.0
# 217  POLYGON ((-111.170232026 19.01577707400003, -1...  183431.0
# 218  POLYGON ((-80.68215272899994 4.037426486000072...  183431.0
# 219  POLYGON ((-90.22271068899994 -0.27334342499995...  183431.0
# 220  POLYGON ((-91.09391784599995 -0.58096068999992...  183431.0
# 221  POLYGON ((-91.24864959699994 -0.67984747899993...  183431.0
# 222  POLYGON ((-124.1523361 41.05706766400004, -124...  183367.0
# 223  POLYGON ((-117.4136322419999 29.18823463600006...  183367.0
# 224  POLYGON ((-117.330311632 21.41966897300006, -1...  183367.0
# 225  POLYGON ((-110.714172363 25.30718421900008, -1...  183367.0
# 226  POLYGON ((-120.118286133 34.47283172600004, -1...  183774.0
# 227  POLYGON ((-117.4136322419999 29.18823463600006...  183774.0
# 228  POLYGON ((-114.638387688 28.39007998000005, -1...  183774.0
# 229  POLYGON ((-111.159618439 19.01535626700007, -1...  183774.0
# 230  POLYGON ((-114.244282766 22.71134688500007, -1...  183774.0
#
#          ...      phylum_nam rl_update seasonal source     species_na subpop  \
# 0        ...        CHORDATA    2012.1        1   None       leucorus   None
# 1        ...        CHORDATA    2012.1        1   None       leucorus   None
# 2        ...        CHORDATA    2012.1        1   None       leucorus   None
# 3        ...        CHORDATA    2012.1        1   None    intercrusma   None
# 4        ...        CHORDATA    2012.1        1   None    intercrusma   None
# 5        ...        CHORDATA    2012.1        1   None    intercrusma   None
# 6        ...        CHORDATA    2012.1        1   None         beebei   None
# 7        ...        CHORDATA    2012.1        1   None         beebei   None
# 8        ...        CHORDATA    2012.1        1   None         beebei   None
# 9        ...        CHORDATA    2012.1        1   None         beebei   None
# 10       ...        CHORDATA    2012.1        1   None         beebei   None
# 11       ...        CHORDATA    2012.1        1   None         beebei   None
# 12       ...        CHORDATA    2012.1        1   None         beebei   None
# 13       ...        CHORDATA    2012.1        1   None         beebei   None
# 14       ...        CHORDATA    2012.1        1   None   rectifraenum   None
# 15       ...        CHORDATA    2012.1        1   None   rectifraenum   None
# 16       ...        CHORDATA    2012.1        1   None   rectifraenum   None
# 17       ...        CHORDATA    2012.2        1   None   punctipinnis   None
# 18       ...        CHORDATA    2012.1        1   None         crusma   None
# 19       ...        CHORDATA    2012.1        1   None         crusma   None
# 20       ...        CHORDATA    2012.1        1   None         crusma   None
# 21       ...        CHORDATA    2012.2        1   None         pembae   None
# 22       ...        CHORDATA    2012.2        1   None         pembae   None
# 23       ...        CHORDATA    2012.2        1   None         pembae   None
# 24       ...        CHORDATA    2012.2        1   None         pembae   None
# 25       ...        CHORDATA    2012.1        1   None      redemptus   None
# 26       ...        CHORDATA    2012.1        1   None      redemptus   None
# 27       ...        CHORDATA    2012.2        1   None        jordani   None
# 28       ...        CHORDATA    2012.2        1   None        jordani   None
# 29       ...        CHORDATA    2012.2        1   None        jordani   None
# ..       ...             ...       ...      ...    ...            ...    ...
# 201      ...        CHORDATA    2012.2        1   None    flavipinnis   None
# 202      ...        CHORDATA    2012.2        1   None    flavipinnis   None
# 203      ...        CHORDATA    2012.2        1   None    flavipinnis   None
# 204      ...        CHORDATA    2012.1        1   None     atrilobata   None
# 205      ...        CHORDATA    2012.1        1   None     atrilobata   None
# 206      ...        CHORDATA    2012.1        1   None     atrilobata   None
# 207      ...        CHORDATA    2012.1        1   None     atrilobata   None
# 208      ...        CHORDATA    2012.1        1   None     atrilobata   None
# 209      ...        CHORDATA    2012.1        1   None     atrilobata   None
# 210      ...        CHORDATA    2012.1        1   None     atrilobata   None
# 211      ...        CHORDATA    2012.1        1   None     atrilobata   None
# 212      ...        CHORDATA    2012.1        1   None     atrilobata   None
# 213      ...        CHORDATA    2012.1        1   None  acapulcoensis   None
# 214      ...        CHORDATA    2012.1        1   None  acapulcoensis   None
# 215      ...        CHORDATA    2012.1        1   None  acapulcoensis   None
# 216      ...        CHORDATA    2012.1        1   None  acapulcoensis   None
# 217      ...        CHORDATA    2012.1        1   None  acapulcoensis   None
# 218      ...        CHORDATA    2012.1        1   None  acapulcoensis   None
# 219      ...        CHORDATA    2012.1        1   None  acapulcoensis   None
# 220      ...        CHORDATA    2012.1        1   None  acapulcoensis   None
# 221      ...        CHORDATA    2012.1        1   None  acapulcoensis   None
# 222      ...        CHORDATA    2012.1        1   None     rubicundus   None
# 223      ...        CHORDATA    2012.1        1   None     rubicundus   None
# 224      ...        CHORDATA    2012.1        1   None     rubicundus   None
# 225      ...        CHORDATA    2012.1        1   None     rubicundus   None
# 226      ...        CHORDATA    2012.1        1   None        hirundo   None
# 227      ...        CHORDATA    2012.1        1   None        hirundo   None
# 228      ...        CHORDATA    2012.1        1   None        hirundo   None
# 229      ...        CHORDATA    2012.1        1   None        hirundo   None
# 230      ...        CHORDATA    2012.1        1   None        hirundo   None
#
#      subspecies  tax_comm  year          area
# 0          None      None  2010  1.939625e+01
# 1          None      None  2010  6.145902e+00
# 2          None      None  2010  2.697207e+00
# 3          None      None  2010  8.746062e+01
# 4          None      None  2010  9.183696e-04
# 5          None      None  2010  2.989001e-15
# 6          None      None  2010  2.732157e+00
# 7          None      None  2010  2.654657e+00
# 8          None      None  2010  2.381573e+00
# 9          None      None  2010  5.363015e-01
# 10         None      None  2010  3.396193e-01
# 11         None      None  2010  1.165597e-02
# 12         None      None  2010  1.912753e-04
# 13         None      None  2010  4.885182e-07
# 14         None      None  2010  2.734773e+01
# 15         None      None  2010  1.047928e+01
# 16         None      None  2010  2.697207e+00
# 17         None      None  2012  1.074924e+01
# 18         None      None  2010  8.724611e+01
# 19         None      None  2010  9.183696e-04
# 20         None      None  2010  2.989001e-15
# 21         None      None  2012  1.132423e+02
# 22         None      None  2012  1.843809e+01
# 23         None      None  2012  1.643766e+01
# 24         None      None  2012  5.287529e-05
# 25         None      None  2010  4.810736e+00
# 26         None      None  2010  2.697207e+00
# 27         None      None  2012  3.867120e+01
# 28         None      None  2012  3.744573e+01
# 29         None      None  2012  1.693946e+01
# ..          ...       ...   ...           ...
# 201        None      None  2012  5.342023e+00
# 202        None      None  2012  4.213801e+00
# 203        None      None  2012  3.849401e+00
# 204        None      None  2010  3.913388e+01
# 205        None      None  2010  2.588695e+01
# 206        None      None  2010  1.624922e+01
# 207        None      None  2010  2.732157e+00
# 208        None      None  2010  2.697207e+00
# 209        None      None  2010  2.654657e+00
# 210        None      None  2010  2.381573e+00
# 211        None      None  2010  1.165597e-02
# 212        None      None  2010  4.885182e-07
# 213        None      None  2010  3.483583e+01
# 214        None      None  2010  1.700187e+01
# 215        None      None  2010  5.981361e+00
# 216        None      None  2010  2.732157e+00
# 217        None      None  2010  2.659590e+00
# 218        None      None  2010  2.654657e+00
# 219        None      None  2010  2.381573e+00
# 220        None      None  2010  1.165597e-02
# 221        None      None  2010  4.885182e-07
# 222        None      None  2010  3.455934e+01
# 223        None      None  2010  3.638651e+00
# 224        None      None  2010  3.273303e+00
# 225        None      None  2010  5.879853e-10
# 226        None      None  2010  5.990467e+00
# 227        None      None  2010  3.638651e+00
# 228        None      None  2010  2.849025e+00
# 229        None      None  2010  2.697207e+00
# 230        None      None  2010  2.237186e+00
#
# [231 rows x 25 columns]

# %%
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
data.plot()

# %%
# Coordinate Reference System (CRS)
data.crs
# Out:
# {'init': 'epsg:4326'}

# %% [markdown]
# ## Writing a shapefile
# Let’s select 50 first rows of the input data and write those into a new
# Shapefile by first selecting the data using index slicing and then write
# the selection into a Shapefile with `gpd.to_file()` -function:

# %%
# Create an output path for the data
out = r"Output/DAMSELFISH_distributions_SELECTION.shp"

# Select first 50 rows
selection = data[0:50]

# Write those rows into a new Shapefile (the default output file format is Shapefile)
selection.to_file(out)

# %% [markdown]
# ## Geometries in Geopandas
#
# Geopandas takes advantage of Shapely’s geometric objects. Geometries are stored in a column called geometry that is a default column name for storing geometric information in geopandas

# %%
# It is possible to use only specific columns by specifying the column name within square brackets []
data['geometry'].head()
# Out:
# 0    POLYGON ((-115.6437454219999 29.71392059300007...
# 1    POLYGON ((-105.589950704 21.89339825500002, -1...
# 2    POLYGON ((-111.159618439 19.01535626700007, -1...
# 3    POLYGON ((-80.86500229899997 -0.77894492099994...
# 4    POLYGON ((-67.33922225599997 -55.6761029239999...
# Name: geometry, dtype: object

# %%
# Make a selection that contains only the first five rows
selection = data[0:5]
for index, row in selection.iterrows():
    poly_area = row['geometry'].area
    print("Polygon area at index {0} is: {1:.3f}".format(index, poly_area))
# Out:
# Polygon area at index 0 is: 19.396
# Polygon area at index 1 is: 6.146
# Polygon area at index 2 is: 2.697
# Polygon area at index 3 is: 87.461
# Polygon area at index 4 is: 0.001

# %%
# Let’s create a new column into our GeoDataFrame where we calculate and 
# store the areas individual polygons:

# Iterate rows one at the time
for index, row in data.iterrows():
    # Update the value in 'area' column with area information at index
    data.loc[index, 'area'] = row['geometry'].area

data['area'].head()
# Out:
# 0    19.396254
# 1     6.145902
# 2     2.697207
# 3    87.460621
# 4     0.000918
# Name: area, dtype: float64

# %%
# Maximum area
max_area = data['area'].max()

# Minimum area
min_area = data['area'].mean()

print("Max area: %s\nMean area: %s" % (round(max_area, 2), round(min_area, 2)))
# Out:
# Max area: 1493.2
# Mean area: 19.96

# %% [markdown]
# ## Creating geometries into a GeoDataFrame
#
# Since geopandas takes advantage of Shapely geometric objects it is possible to create a Shapefile from a scratch by passing Shapely’s geometric objects into the GeoDataFrame. This is useful as it makes it easy to convert e.g. a text file that contains coordinates into a Shapefile.

# %%
# Import necessary modules first
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon
import fiona

# Create an empty geopandas GeoDataFrame
newdata = gpd.GeoDataFrame()

# %%
# Create a new column called 'geometry' to the GeoDataFrame
newdata['geometry'] = None
newdata
# Out:
# Empty GeoDataFrame
# Columns: [geometry]
# Index: []

# %%
# Coordinates of the Helsinki Senate square in Decimal Degrees
coordinates = [(24.950899, 60.169158), (24.953492, 60.169158), (24.953510, 60.170104), (24.950958, 60.169990)]

# Create a Shapely polygon from the coordinate-tuple list
poly = Polygon(coordinates)

# Let's see what we have
poly

# %%
# Insert the polygon into 'geometry' -column at index 0
newdata.loc[0, 'geometry'] = poly
newdata
# Out:
#                                             geometry
# 0  POLYGON ((24.950899 60.169158, 24.953492 60.16...

# %%
# Add a new column and insert data
newdata.loc[0, 'Location'] = 'Senaatintori'
newdata
# Out:
#                                             geometry      Location
# 0  POLYGON ((24.950899 60.169158, 24.953492 60.16...  Senaatintori

# %%
# Import specific function 'from_epsg' from fiona module
from fiona.crs import from_epsg

# Set the GeoDataFrame's coordinate system to WGS84
newdata.crs = from_epsg(4326)

# Let's see how the crs definition looks like
newdata.crs
# Out:
# {'init': 'epsg:4326', 'no_defs': True}

# %%
# Determine the output path for the Shapefile
outfp = r"Output/Senaatintori.shp"

# Write the data into that Shapefile
newdata.to_file(outfp)

# %% [markdown]
# ## Grouping data
#
# One really useful function that can be used in Pandas/Geopandas is .groupby(). This function groups data based on values on selected column(s).

# %%
# Group the data by column 'binomial'
grouped = data.groupby('binomial')
# Let's see what we got
list(grouped)
# Out:
# [('Abudefduf concolor',                binomial category  \
#   183  Abudefduf concolor       LC
#   184  Abudefduf concolor       LC
#   185  Abudefduf concolor       LC
#   186  Abudefduf concolor       LC
#   187  Abudefduf concolor       LC
#   188  Abudefduf concolor       LC
#
#                                                 citation      class_name  \
#   183  International Union for Conservation of Nature...  ACTINOPTERYGII
#   184  International Union for Conservation of Nature...  ACTINOPTERYGII
#   185  International Union for Conservation of Nature...  ACTINOPTERYGII
#   186  International Union for Conservation of Nature...  ACTINOPTERYGII
#   187  International Union for Conservation of Nature...  ACTINOPTERYGII
#   188  International Union for Conservation of Nature...  ACTINOPTERYGII
#
#       compiler dist_comm     family_nam genus_name  \
#   183     IUCN      None  POMACENTRIDAE  Abudefduf
#   184     IUCN      None  POMACENTRIDAE  Abudefduf
#   185     IUCN      None  POMACENTRIDAE  Abudefduf
#   186     IUCN      None  POMACENTRIDAE  Abudefduf
#   187     IUCN      None  POMACENTRIDAE  Abudefduf
#   188     IUCN      None  POMACENTRIDAE  Abudefduf
#
#                                                 geometry     id_no  \
#   183  POLYGON ((-91.05594361199996 13.91150650800006...  183483.0
#   184  POLYGON ((-86.13105102199995 5.598867493000057...  183483.0
#   185  POLYGON ((-80.68215272899994 4.037426486000072...  183483.0
#   186  POLYGON ((-90.22271068899994 -0.27334342499995...  183483.0
#   187  POLYGON ((-91.09391784599995 -0.58096068999992...  183483.0
#   188  POLYGON ((-91.24864959699994 -0.67984747899993...  183483.0
#
#            ...      phylum_nam rl_update seasonal source  species_na subpop  \
#   183      ...        CHORDATA    2012.1        1   None    concolor   None
#   184      ...        CHORDATA    2012.1        1   None    concolor   None
#   185      ...        CHORDATA    2012.1        1   None    concolor   None
#   186      ...        CHORDATA    2012.1        1   None    concolor   None
#   187      ...        CHORDATA    2012.1        1   None    concolor   None
#   188      ...        CHORDATA    2012.1        1   None    concolor   None
#
#        subspecies  tax_comm  year          area
#   183        None      None  2010  3.451845e+01
#   184        None      None  2010  2.732157e+00
#   185        None      None  2010  2.654657e+00
#   186        None      None  2010  2.381573e+00
#   187        None      None  2010  1.165597e-02
#   188        None      None  2010  4.885182e-07
#
#   [6 rows x 25 columns]),
#  ('Abudefduf declivifrons',                    binomial category  \
#   158  Abudefduf declivifrons       LC
#   159  Abudefduf declivifrons       LC
#   160  Abudefduf declivifrons       LC
#
#                                                 citation      class_name  \
#   158  International Union for Conservation of Nature...  ACTINOPTERYGII
#   159  International Union for Conservation of Nature...  ACTINOPTERYGII
#   160  International Union for Conservation of Nature...  ACTINOPTERYGII
#
#       compiler dist_comm     family_nam genus_name  \
#   158     IUCN      None  POMACENTRIDAE  Abudefduf
#   159     IUCN      None  POMACENTRIDAE  Abudefduf
#   160     IUCN      None  POMACENTRIDAE  Abudefduf
#
#                                                 geometry     id_no    ...      \
#   158  POLYGON ((-106.72576642 23.59774532600005, -10...  183460.0    ...
#   159  POLYGON ((-111.710365312 28.47387119800004, -1...  183460.0    ...
#   160  POLYGON ((-90.09187344499998 13.72481517500006...  183460.0    ...
#
#       phylum_nam rl_update seasonal source    species_na subpop  subspecies  \
#   158   CHORDATA    2012.1        1   None  declivifrons   None        None
#   159   CHORDATA    2012.1        1   None  declivifrons   None        None
#   160   CHORDATA    2012.1        1   None  declivifrons   None        None
#
#        tax_comm  year       area
#   158      None  2010  17.001873
#   159      None  2010  12.957834
#   160      None  2010   9.708056
#
#   [3 rows x 25 columns]),
#  ('Abudefduf troschelii',                  binomial category  \
#   189  Abudefduf troschelii       LC
#   190  Abudefduf troschelii       LC
#   191  Abudefduf troschelii       LC
#   192  Abudefduf troschelii       LC
#   193  Abudefduf troschelii       LC
#   194  Abudefduf troschelii       LC
#   195  Abudefduf troschelii       LC
#   196  Abudefduf troschelii       LC
#   197  Abudefduf troschelii       LC
#   198  Abudefduf troschelii       LC
#
#                                                 citation      class_name  \
#   189  International Union for Conservation of Nature...  ACTINOPTERYGII
#   190  International Union for Conservation of Nature...  ACTINOPTERYGII
#   191  International Union for Conservation of Nature...  ACTINOPTERYGII
#   192  International Union for Conservation of Nature...  ACTINOPTERYGII
#   193  International Union for Conservation of Nature...  ACTINOPTERYGII
#   194  International Union for Conservation of Nature...  ACTINOPTERYGII
#   195  International Union for Conservation of Nature...  ACTINOPTERYGII
#   196  International Union for Conservation of Nature...  ACTINOPTERYGII
#   197  International Union for Conservation of Nature...  ACTINOPTERYGII
#   198  International Union for Conservation of Nature...  ACTINOPTERYGII
#
#       compiler dist_comm     family_nam genus_name  \
#   189     IUCN      None  POMACENTRIDAE  Abudefduf
#   190     IUCN      None  POMACENTRIDAE  Abudefduf
#   191     IUCN      None  POMACENTRIDAE  Abudefduf
#   192     IUCN      None  POMACENTRIDAE  Abudefduf
#   193     IUCN      None  POMACENTRIDAE  Abudefduf
#   194     IUCN      None  POMACENTRIDAE  Abudefduf
#   195     IUCN      None  POMACENTRIDAE  Abudefduf
#   196     IUCN      None  POMACENTRIDAE  Abudefduf
#   197     IUCN      None  POMACENTRIDAE  Abudefduf
#   198     IUCN      None  POMACENTRIDAE  Abudefduf
#
#                                                 geometry     id_no  \
#   189  POLYGON ((-90.09187344499998 13.72481517500006...  183397.0
#   190  POLYGON ((-121.284812927 35.67465591400003, -1...  183397.0
#   191  POLYGON ((-106.72576642 23.59774532600005, -10...  183397.0
#   192  POLYGON ((-86.13105102199995 5.598867493000057...  183397.0
#   193  POLYGON ((-111.159618439 19.01535626700007, -1...  183397.0
#   194  POLYGON ((-108.302926059 10.35825927300004, -1...  183397.0
#   195  POLYGON ((-80.68215272899994 4.037426486000072...  183397.0
#   196  POLYGON ((-90.22271068899994 -0.27334342499995...  183397.0
#   197  POLYGON ((-91.09391784599995 -0.58096068999992...  183397.0
#   198  POLYGON ((-91.24864959699994 -0.67984747899993...  183397.0
#
#            ...      phylum_nam rl_update seasonal source  species_na subpop  \
#   189      ...        CHORDATA    2012.1        1   None  troschelii   None
#   190      ...        CHORDATA    2012.1        1   None  troschelii   None
#   191      ...        CHORDATA    2012.1        1   None  troschelii   None
#   192      ...        CHORDATA    2012.1        1   None  troschelii   None
#   193      ...        CHORDATA    2012.1        1   None  troschelii   None
#   194      ...        CHORDATA    2012.1        1   None  troschelii   None
#   195      ...        CHORDATA    2012.1        1   None  troschelii   None
#   196      ...        CHORDATA    2012.1        1   None  troschelii   None
#   197      ...        CHORDATA    2012.1        1   None  troschelii   None
#   198      ...        CHORDATA    2012.1        1   None  troschelii   None
#
#        subspecies  tax_comm  year          area
#   189        None      None  2010  4.322931e+01
#   190        None      None  2010  3.893626e+01
#   191        None      None  2010  1.700187e+01
#   192        None      None  2010  2.732157e+00
#   193        None      None  2010  2.697207e+00
#   194        None      None  2010  2.683781e+00
#   195        None      None  2010  2.654657e+00
#   196        None      None  2010  2.381573e+00
#   197        None      None  2010  1.165597e-02
#   198        None      None  2010  4.885182e-07
#
#   [10 rows x 25 columns]),
#  ('Amphiprion sandaracinos',                     binomial category  \
#   65   Amphiprion sandaracinos       LC
#   66   Amphiprion sandaracinos       LC
#   67   Amphiprion sandaracinos       LC
#   68   Amphiprion sandaracinos       LC
#   69   Amphiprion sandaracinos       LC
#   70   Amphiprion sandaracinos       LC
#   71   Amphiprion sandaracinos       LC
#   72   Amphiprion sandaracinos       LC
#   73   Amphiprion sandaracinos       LC
#   74   Amphiprion sandaracinos       LC
#   75   Amphiprion sandaracinos       LC
#   76   Amphiprion sandaracinos       LC
#   77   Amphiprion sandaracinos       LC
#   78   Amphiprion sandaracinos       LC
#   79   Amphiprion sandaracinos       LC
#   80   Amphiprion sandaracinos       LC
#   81   Amphiprion sandaracinos       LC
#   82   Amphiprion sandaracinos       LC
#   83   Amphiprion sandaracinos       LC
#   84   Amphiprion sandaracinos       LC
#   85   Amphiprion sandaracinos       LC
#   86   Amphiprion sandaracinos       LC
#   87   Amphiprion sandaracinos       LC
#   88   Amphiprion sandaracinos       LC
#   89   Amphiprion sandaracinos       LC
#   90   Amphiprion sandaracinos       LC
#   91   Amphiprion sandaracinos       LC
#   92   Amphiprion sandaracinos       LC
#   93   Amphiprion sandaracinos       LC
#   94   Amphiprion sandaracinos       LC
#   95   Amphiprion sandaracinos       LC
#   96   Amphiprion sandaracinos       LC
#   97   Amphiprion sandaracinos       LC
#   98   Amphiprion sandaracinos       LC
#   99   Amphiprion sandaracinos       LC
#   100  Amphiprion sandaracinos       LC
#   101  Amphiprion sandaracinos       LC
#   102  Amphiprion sandaracinos       LC
#   103  Amphiprion sandaracinos       LC
#   104  Amphiprion sandaracinos       LC
#   105  Amphiprion sandaracinos       LC
#   106  Amphiprion sandaracinos       LC
#   107  Amphiprion sandaracinos       LC
#   108  Amphiprion sandaracinos       LC
#   109  Amphiprion sandaracinos       LC
#   110  Amphiprion sandaracinos       LC
#   111  Amphiprion sandaracinos       LC
#   112  Amphiprion sandaracinos       LC
#   113  Amphiprion sandaracinos       LC
#   114  Amphiprion sandaracinos       LC
#   115  Amphiprion sandaracinos       LC
#
#                                                 citation      class_name  \
#   65   International Union for Conservation of Nature...  ACTINOPTERYGII
#   66   International Union for Conservation of Nature...  ACTINOPTERYGII
#   67   International Union for Conservation of Nature...  ACTINOPTERYGII
#   68   International Union for Conservation of Nature...  ACTINOPTERYGII
#   69   International Union for Conservation of Nature...  ACTINOPTERYGII
#   70   International Union for Conservation of Nature...  ACTINOPTERYGII
#   71   International Union for Conservation of Nature...  ACTINOPTERYGII
#   72   International Union for Conservation of Nature...  ACTINOPTERYGII
#   73   International Union for Conservation of Nature...  ACTINOPTERYGII
#   74   International Union for Conservation of Nature...  ACTINOPTERYGII
#   75   International Union for Conservation of Nature...  ACTINOPTERYGII
#   76   International Union for Conservation of Nature...  ACTINOPTERYGII
#   77   International Union for Conservation of Nature...  ACTINOPTERYGII
#   78   International Union for Conservation of Nature...  ACTINOPTERYGII
#   79   International Union for Conservation of Nature...  ACTINOPTERYGII
#   80   International Union for Conservation of Nature...  ACTINOPTERYGII
#   81   International Union for Conservation of Nature...  ACTINOPTERYGII
#   82   International Union for Conservation of Nature...  ACTINOPTERYGII
#   83   International Union for Conservation of Nature...  ACTINOPTERYGII
#   84   International Union for Conservation of Nature...  ACTINOPTERYGII
#   85   International Union for Conservation of Nature...  ACTINOPTERYGII
#   86   International Union for Conservation of Nature...  ACTINOPTERYGII
#   87   International Union for Conservation of Nature...  ACTINOPTERYGII
#   88   International Union for Conservation of Nature...  ACTINOPTERYGII
#   89   International Union for Conservation of Nature...  ACTINOPTERYGII
#   90   International Union for Conservation of Nature...  ACTINOPTERYGII
#   91   International Union for Conservation of Nature...  ACTINOPTERYGII
#   92   International Union for Conservation of Nature...  ACTINOPTERYGII
#   93   International Union for Conservation of Nature...  ACTINOPTERYGII
#   94   International Union for Conservation of Nature...  ACTINOPTERYGII
#   95   International Union for Conservation of Nature...  ACTINOPTERYGII
#   96   International Union for Conservation of Nature...  ACTINOPTERYGII
#   97   International Union for Conservation of Nature...  ACTINOPTERYGII
#   98   International Union for Conservation of Nature...  ACTINOPTERYGII
#   99   International Union for Conservation of Nature...  ACTINOPTERYGII
#   100  International Union for Conservation of Nature...  ACTINOPTERYGII
#   101  International Union for Conservation of Nature...  ACTINOPTERYGII
#   102  International Union for Conservation of Nature...  ACTINOPTERYGII
#   103  International Union for Conservation of Nature...  ACTINOPTERYGII
#   104  International Union for Conservation of Nature...  ACTINOPTERYGII
#   105  International Union for Conservation of Nature...  ACTINOPTERYGII
#   106  International Union for Conservation of Nature...  ACTINOPTERYGII
#   107  International Union for Conservation of Nature...  ACTINOPTERYGII
#   108  International Union for Conservation of Nature...  ACTINOPTERYGII
#   109  International Union for Conservation of Nature...  ACTINOPTERYGII
#   110  International Union for Conservation of Nature...  ACTINOPTERYGII
#   111  International Union for Conservation of Nature...  ACTINOPTERYGII
#   112  International Union for Conservation of Nature...  ACTINOPTERYGII
#   113  International Union for Conservation of Nature...  ACTINOPTERYGII
#   114  International Union for Conservation of Nature...  ACTINOPTERYGII
#   115  International Union for Conservation of Nature...  ACTINOPTERYGII
#
#       compiler dist_comm     family_nam  genus_name  \
#   65      None      None  POMACENTRIDAE  Amphiprion
#   66      None      None  POMACENTRIDAE  Amphiprion
#   67      None      None  POMACENTRIDAE  Amphiprion
#   68      None      None  POMACENTRIDAE  Amphiprion
#   69      None      None  POMACENTRIDAE  Amphiprion
#   70      None      None  POMACENTRIDAE  Amphiprion
#   71      None      None  POMACENTRIDAE  Amphiprion
#   72      None      None  POMACENTRIDAE  Amphiprion
#   73      None      None  POMACENTRIDAE  Amphiprion
#   74      None      None  POMACENTRIDAE  Amphiprion
#   75      None      None  POMACENTRIDAE  Amphiprion
#   76      None      None  POMACENTRIDAE  Amphiprion
#   77      None      None  POMACENTRIDAE  Amphiprion
#   78      None      None  POMACENTRIDAE  Amphiprion
#   79      None      None  POMACENTRIDAE  Amphiprion
#   80      None      None  POMACENTRIDAE  Amphiprion
#   81      None      None  POMACENTRIDAE  Amphiprion
#   82      None      None  POMACENTRIDAE  Amphiprion
#   83      None      None  POMACENTRIDAE  Amphiprion
#   84      None      None  POMACENTRIDAE  Amphiprion
#   85      None      None  POMACENTRIDAE  Amphiprion
#   86      None      None  POMACENTRIDAE  Amphiprion
#   87      None      None  POMACENTRIDAE  Amphiprion
#   88      None      None  POMACENTRIDAE  Amphiprion
#   89      None      None  POMACENTRIDAE  Amphiprion
#   90      None      None  POMACENTRIDAE  Amphiprion
#   91      None      None  POMACENTRIDAE  Amphiprion
#   92      None      None  POMACENTRIDAE  Amphiprion
#   93      None      None  POMACENTRIDAE  Amphiprion
#   94      None      None  POMACENTRIDAE  Amphiprion
#   95      None      None  POMACENTRIDAE  Amphiprion
#   96      None      None  POMACENTRIDAE  Amphiprion
#   97      None      None  POMACENTRIDAE  Amphiprion
#   98      None      None  POMACENTRIDAE  Amphiprion
#   99      None      None  POMACENTRIDAE  Amphiprion
#   100     None      None  POMACENTRIDAE  Amphiprion
#   101     None      None  POMACENTRIDAE  Amphiprion
#   102     None      None  POMACENTRIDAE  Amphiprion
#   103     None      None  POMACENTRIDAE  Amphiprion
#   104     None      None  POMACENTRIDAE  Amphiprion
#   105     None      None  POMACENTRIDAE  Amphiprion
#   106     None      None  POMACENTRIDAE  Amphiprion
#   107     None      None  POMACENTRIDAE  Amphiprion
#   108     None      None  POMACENTRIDAE  Amphiprion
#   109     None      None  POMACENTRIDAE  Amphiprion
#   110     None      None  POMACENTRIDAE  Amphiprion
#   111     None      None  POMACENTRIDAE  Amphiprion
#   112     None      None  POMACENTRIDAE  Amphiprion
#   113     None      None  POMACENTRIDAE  Amphiprion
#   114     None      None  POMACENTRIDAE  Amphiprion
#   115     None      None  POMACENTRIDAE  Amphiprion
#
#                                                 geometry     id_no  \
#   65   POLYGON ((116.7295 -8.686164406999978, 116.727...  154812.0
#   66   POLYGON ((117.9343 -18.56846440699996, 117.983...  154812.0
#   67   POLYGON ((129.5599000000001 28.86163559200003,...  154812.0
#   68   POLYGON ((133.0940000000001 4.782535593000034,...  154812.0
#   69   POLYGON ((105.601968915 -10.50437547999996, 10...  154812.0
#   70   POLYGON ((130.6557552920001 -0.084297320999951...  154812.0
#   71   POLYGON ((117.9343 -18.56846440699996, 117.977...  154812.0
#   72   POLYGON ((118.3526000000001 4.641235593000033,...  154812.0
#   73   POLYGON ((158.4622000000001 -7.581064406999928...  154812.0
#   74   POLYGON ((124.8618 -16.41866440699994, 124.866...  154812.0
#   75   POLYGON ((118.5292000000001 2.156735592000075,...  154812.0
#   76   POLYGON ((151.1304000000001 -8.611764406999953...  154812.0
#   77   POLYGON ((117.4697000000001 -0.385064406999958...  154812.0
#   78   POLYGON ((161.3837357760001 -9.538045704999945...  154812.0
#   79   POLYGON ((149.0693000000001 -6.138464406999958...  154812.0
#   80   POLYGON ((130.9021455880001 -0.311590273999968...  154812.0
#   81   POLYGON ((157.0911000000001 -8.171564406999948...  154812.0
#   82   POLYGON ((118.590198546 -20.32759245299997, 11...  154812.0
#   83   POLYGON ((126.0376000000001 9.247435593000034,...  154812.0
#   84   POLYGON ((142.1067983820001 -3.044080821999955...  154812.0
#   85   POLYGON ((158.2702 -7.406664407999926, 158.274...  154812.0
#   86   POLYGON ((131.2804000000001 -1.389164407999942...  154812.0
#   87   POLYGON ((130.9222492880001 -0.328890899999976...  154812.0
#   88   POLYGON ((144.4193868650001 -3.808786299999952...  154812.0
#   89   POLYGON ((148.6395000000001 -9.088564407999968...  154812.0
#   90   POLYGON ((144.366666288 -3.80249977099993, 144...  154812.0
#   91   POLYGON ((122.764 7.764735593000069, 122.7657 ...  154812.0
#   92   POLYGON ((127.6635086490001 0.8763981940000463...  154812.0
#   93   POLYGON ((117.4278 -0.870964406999974, 117.432...  154812.0
#   94   POLYGON ((124.8661113710001 -16.41978775599995...  154812.0
#   95   POLYGON ((123.8337 -16.36116440699993, 123.837...  154812.0
#   96   POLYGON ((147.4178000000001 -2.044064406999951...  154812.0
#   97   POLYGON ((119.3720000000001 -5.434064406999937...  154812.0
#   98   POLYGON ((157.8133 -7.450564407999934, 157.816...  154812.0
#   99   POLYGON ((119.9838000000001 5.864935593000041,...  154812.0
#   100  POLYGON ((149.9624000000001 -2.492164406999962...  154812.0
#   101  POLYGON ((158.5262 -7.656964406999975, 158.525...  154812.0
#   102  POLYGON ((119.6378000000001 10.65743559200007,...  154812.0
#   103  POLYGON ((125.9695567540001 9.713912795000056,...  154812.0
#   104  POLYGON ((157.8033 -7.447064406999971, 157.806...  154812.0
#   105  POLYGON ((119.6251422290001 10.68029203300006,...  154812.0
#   106  POLYGON ((117.9478 1.087935593000054, 117.9492...  154812.0
#   107  POLYGON ((159.8860874610001 -8.556702216999952...  154812.0
#   108  POLYGON ((119.398155941 -5.470141634999948, 11...  154812.0
#   109  POLYGON ((150.4405040910001 -2.664806563999946...  154812.0
#   110  POLYGON ((129.291125026 28.16155555900008, 129...  154812.0
#   111  POLYGON ((118.7386 9.665035592000038, 118.7424...  154812.0
#   112  POLYGON ((117.293478809 -0.8105510049999793, 1...  154812.0
#   113  POLYGON ((123.4329 -16.50866440699997, 123.433...  154812.0
#   114  POLYGON ((129.861543362 -1.232989566999947, 12...  154812.0
#   115  POLYGON ((124.105561705 -8.371067348999929, 12...  154812.0
#
#            ...      phylum_nam rl_update seasonal source    species_na subpop  \
#   65       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   66       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   67       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   68       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   69       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   70       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   71       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   72       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   73       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   74       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   75       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   76       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   77       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   78       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   79       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   80       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   81       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   82       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   83       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   84       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   85       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   86       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   87       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   88       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   89       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   90       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   91       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   92       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   93       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   94       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   95       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   96       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   97       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   98       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   99       ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   100      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   101      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   102      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   103      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   104      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   105      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   106      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   107      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   108      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   109      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   110      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   111      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   112      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   113      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   114      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#   115      ...        CHORDATA    2012.2        1   None  sandaracinos   None
#
#        subspecies  tax_comm  year          area
#   65         None      None  2012  4.357094e+02
#   66         None      None  2012  4.181630e+01
#   67         None      None  2012  1.043228e+01
#   68         None      None  2012  6.014647e+00
#   69         None      None  2012  2.284042e-02
#   70         None      None  2012  1.824788e-02
#   71         None      None  2012  2.709785e-03
#   72         None      None  2012  1.930246e-03
#   73         None      None  2012  1.050508e-03
#   74         None      None  2012  3.971581e-04
#   75         None      None  2012  3.482750e-04
#   76         None      None  2012  2.342062e-04
#   77         None      None  2012  9.530080e-05
#   78         None      None  2012  7.849592e-05
#   79         None      None  2012  5.570778e-05
#   80         None      None  2012  5.283101e-05
#   81         None      None  2012  4.918499e-05
#   82         None      None  2012  4.904508e-05
#   83         None      None  2012  4.845949e-05
#   84         None      None  2012  4.559019e-05
#   85         None      None  2012  4.196000e-05
#   86         None      None  2012  4.166351e-05
#   87         None      None  2012  4.150160e-05
#   88         None      None  2012  4.140742e-05
#   89         None      None  2012  4.003461e-05
#   90         None      None  2012  3.828717e-05
#   91         None      None  2012  2.625506e-05
#   92         None      None  2012  2.554791e-05
#   93         None      None  2012  2.299000e-05
#   94         None      None  2012  2.110408e-05
#   95         None      None  2012  1.902157e-05
#   96         None      None  2012  1.487893e-05
#   97         None      None  2012  1.375837e-05
#   98         None      None  2012  1.357500e-05
#   99         None      None  2012  1.301500e-05
#   100        None      None  2012  1.136290e-05
#   101        None      None  2012  9.174532e-06
#   102        None      None  2012  7.646189e-06
#   103        None      None  2012  4.383074e-06
#   104        None      None  2012  4.140002e-06
#   105        None      None  2012  4.122709e-06
#   106        None      None  2012  3.940000e-06
#   107        None      None  2012  2.418591e-06
#   108        None      None  2012  2.278114e-06
#   109        None      None  2012  1.466522e-06
#   110        None      None  2012  5.945575e-07
#   111        None      None  2012  5.786996e-07
#   112        None      None  2012  4.945339e-07
#   113        None      None  2012  5.140871e-08
#   114        None      None  2012  2.065278e-08
#   115        None      None  2012  1.277182e-08
#
#   [51 rows x 25 columns]),
#  ('Azurina eupalama',              binomial category  \
#   134  Azurina eupalama       CR
#   135  Azurina eupalama       CR
#   136  Azurina eupalama       CR
#
#                                                 citation      class_name  \
#   134  International Union for Conservation of Nature...  ACTINOPTERYGII
#   135  International Union for Conservation of Nature...  ACTINOPTERYGII
#   136  International Union for Conservation of Nature...  ACTINOPTERYGII
#
#       compiler dist_comm     family_nam genus_name  \
#   134     IUCN      None  POMACENTRIDAE    Azurina
#   135     IUCN      None  POMACENTRIDAE    Azurina
#   136     IUCN      None  POMACENTRIDAE    Azurina
#
#                                                 geometry     id_no  \
#   134  POLYGON ((-90.22271068899994 -0.27334342499995...  184017.0
#   135  POLYGON ((-91.09391784599995 -0.58096068999992...  184017.0
#   136  POLYGON ((-91.24864959699994 -0.67984747899993...  184017.0
#
#            ...      phylum_nam rl_update seasonal source  species_na subpop  \
#   134      ...        CHORDATA    2012.1        1   None    eupalama   None
#   135      ...        CHORDATA    2012.1        1   None    eupalama   None
#   136      ...        CHORDATA    2012.1        1   None    eupalama   None
#
#        subspecies  tax_comm  year          area
#   134        None      None  2010  2.381573e+00
#   135        None      None  2010  1.165597e-02
#   136        None      None  2010  4.885182e-07
#
#   [3 rows x 25 columns]),
#  ('Azurina hirundo',             binomial category  \
#   226  Azurina hirundo       NT
#   227  Azurina hirundo       NT
#   228  Azurina hirundo       NT
#   229  Azurina hirundo       NT
#   230  Azurina hirundo       NT
#
#                                                 citation      class_name  \
#   226  International Union for Conservation of Nature...  ACTINOPTERYGII
#   227  International Union for Conservation of Nature...  ACTINOPTERYGII
#   228  International Union for Conservation of Nature...  ACTINOPTERYGII
#   229  International Union for Conservation of Nature...  ACTINOPTERYGII
#   230  International Union for Conservation of Nature...  ACTINOPTERYGII
#
#       compiler dist_comm     family_nam genus_name  \
#   226     IUCN      None  POMACENTRIDAE    Azurina
#   227     IUCN      None  POMACENTRIDAE    Azurina
#   228     IUCN      None  POMACENTRIDAE    Azurina
#   229     IUCN      None  POMACENTRIDAE    Azurina
#   230     IUCN      None  POMACENTRIDAE    Azurina
#
#                                                 geometry     id_no    ...     \
#   226  POLYGON ((-120.118286133 34.47283172600004, -1...  183774.0    ...
#   227  POLYGON ((-117.4136322419999 29.18823463600006...  183774.0    ...
#   228  POLYGON ((-114.638387688 28.39007998000005, -1...  183774.0    ...
#   229  POLYGON ((-111.159618439 19.01535626700007, -1...  183774.0    ...
#   230  POLYGON ((-114.244282766 22.71134688500007, -1...  183774.0    ...
#
#       phylum_nam rl_update seasonal source  species_na subpop  subspecies  \
#   226   CHORDATA    2012.1        1   None     hirundo   None        None
#   227   CHORDATA    2012.1        1   None     hirundo   None        None
#   228   CHORDATA    2012.1        1   None     hirundo   None        None
#   229   CHORDATA    2012.1        1   None     hirundo   None        None
#   230   CHORDATA    2012.1        1   None     hirundo   None        None
#
#        tax_comm  year      area
#   226      None  2010  5.990467
#   227      None  2010  3.638651
#   228      None  2010  2.849025
#   229      None  2010  2.697207
#   230      None  2010  2.237186
#
#   [5 rows x 25 columns]),
#  ('Chromis alpha',           binomial category  \
#   161  Chromis alpha       LC
#   162  Chromis alpha       LC
#   163  Chromis alpha       LC
#   164  Chromis alpha       LC
#   165  Chromis alpha       LC
#   166  Chromis alpha       LC
#   167  Chromis alpha       LC
#   168  Chromis alpha       LC
#   169  Chromis alpha       LC
#   170  Chromis alpha       LC
#   171  Chromis alpha       LC
#   172  Chromis alpha       LC
#   173  Chromis alpha       LC
#   174  Chromis alpha       LC
#
#                                                 citation      class_name  \
#   161  International Union for Conservation of Nature...  ACTINOPTERYGII
#   162  International Union for Conservation of Nature...  ACTINOPTERYGII
#   163  International Union for Conservation of Nature...  ACTINOPTERYGII
#   164  International Union for Conservation of Nature...  ACTINOPTERYGII
#   165  International Union for Conservation of Nature...  ACTINOPTERYGII
#   166  International Union for Conservation of Nature...  ACTINOPTERYGII
#   167  International Union for Conservation of Nature...  ACTINOPTERYGII
#   168  International Union for Conservation of Nature...  ACTINOPTERYGII
#   169  International Union for Conservation of Nature...  ACTINOPTERYGII
#   170  International Union for Conservation of Nature...  ACTINOPTERYGII
#   171  International Union for Conservation of Nature...  ACTINOPTERYGII
#   172  International Union for Conservation of Nature...  ACTINOPTERYGII
#   173  International Union for Conservation of Nature...  ACTINOPTERYGII
#   174  International Union for Conservation of Nature...  ACTINOPTERYGII
#
#       compiler dist_comm     family_nam genus_name  \
#   161     None      None  POMACENTRIDAE    Chromis
#   162     None      None  POMACENTRIDAE    Chromis
#   163     None      None  POMACENTRIDAE    Chromis
#   164     None      None  POMACENTRIDAE    Chromis
#   165     None      None  POMACENTRIDAE    Chromis
#   166     None      None  POMACENTRIDAE    Chromis
#   167     None      None  POMACENTRIDAE    Chromis
#   168     None      None  POMACENTRIDAE    Chromis
#   169     None      None  POMACENTRIDAE    Chromis
#   170     None      None  POMACENTRIDAE    Chromis
#   171     None      None  POMACENTRIDAE    Chromis
#   172     None      None  POMACENTRIDAE    Chromis
#   173     None      None  POMACENTRIDAE    Chromis
#   174     None      None  POMACENTRIDAE    Chromis
#
#                                                 geometry     id_no     ...       \
#   161  POLYGON ((125.5376129150001 9.774582862000045,...  154760.0     ...
#   162  POLYGON ((-153.839732405 -8.094351700999937, -...  154760.0     ...
#   163  POLYGON ((142.7490174950001 31.58880687300007,...  154760.0     ...
#   164  POLYGON ((-178.182685629 -7.355219766999937, -...  154760.0     ...
#   165  POLYGON ((179.9999885410001 -20.28229556499997...  154760.0     ...
#   166  POLYGON ((179.8143005370001 -16.34261131299996...  154760.0     ...
#   167  POLYGON ((179.996307373 -16.17172241199995, 17...  154760.0     ...
#   168  POLYGON ((-146.34274292 -16.19295120299995, -1...  154760.0     ...
#   169  POLYGON ((-140.609481812 -21.71556472799995, -...  154760.0     ...
#   170  POLYGON ((-144.628601074 -15.74538421599993, -...  154760.0     ...
#   171  POLYGON ((118.5263595580001 2.160361052000042,...  154760.0     ...
#   172  POLYGON ((179.8121643070001 -16.22794532799998...  154760.0     ...
#   173  POLYGON ((126.5589447020001 7.583111286000076,...  154760.0     ...
#   174  POLYGON ((144.7899100980001 13.41619277200004,...  154760.0     ...
#
#       phylum_nam rl_update seasonal source  species_na subpop  subspecies  \
#   161   CHORDATA    2012.2        1   None       alpha   None        None
#   162   CHORDATA    2012.2        1   None       alpha   None        None
#   163   CHORDATA    2012.2        1   None       alpha   None        None
#   164   CHORDATA    2012.2        1   None       alpha   None        None
#   165   CHORDATA    2012.2        1   None       alpha   None        None
#   166   CHORDATA    2012.2        1   None       alpha   None        None
#   167   CHORDATA    2012.2        1   None       alpha   None        None
#   168   CHORDATA    2012.2        1   None       alpha   None        None
#   169   CHORDATA    2012.2        1   None       alpha   None        None
#   170   CHORDATA    2012.2        1   None       alpha   None        None
#   171   CHORDATA    2012.2        1   None       alpha   None        None
#   172   CHORDATA    2012.2        1   None       alpha   None        None
#   173   CHORDATA    2012.2        1   None       alpha   None        None
#   174   CHORDATA    2012.2        1   None       alpha   None        None
#
#        tax_comm  year         area
#   161      None  2012  1493.200918
#   162      None  2012   760.601478
#   163      None  2012    61.657100
#   164      None  2012    30.097345
#   165      None  2012     0.067401
#   166      None  2012     0.051022
#   167      None  2012     0.025462
#   168      None  2012     0.002912
#   169      None  2012     0.002079
#   170      None  2012     0.000480
#   171      None  2012     0.000351
#   172      None  2012     0.000172
#   173      None  2012     0.000053
#   174      None  2012     0.000043
#
#   [14 rows x 25 columns]),
#  ('Chromis alta',
#            binomial category                                           citation  \
#   147  Chromis alta       LC  International Union for Conservation of Nature...
#   148  Chromis alta       LC  International Union for Conservation of Nature...
#   149  Chromis alta       LC  International Union for Conservation of Nature...
#   150  Chromis alta       LC  International Union for Conservation of Nature...
#   151  Chromis alta       LC  International Union for Conservation of Nature...
#   152  Chromis alta       LC  International Union for Conservation of Nature...
#   153  Chromis alta       LC  International Union for Conservation of Nature...
#   154  Chromis alta       LC  International Union for Conservation of Nature...
#   155  Chromis alta       LC  International Union for Conservation of Nature...
#   156  Chromis alta       LC  International Union for Conservation of Nature...
#   157  Chromis alta       LC  International Union for Conservation of Nature...
#
#            class_name compiler dist_comm     family_nam genus_name  \
#   147  ACTINOPTERYGII     IUCN      None  POMACENTRIDAE    Chromis
#   148  ACTINOPTERYGII     IUCN      None  POMACENTRIDAE    Chromis
#   149  ACTINOPTERYGII     IUCN      None  POMACENTRIDAE    Chromis
#   150  ACTINOPTERYGII     IUCN      None  POMACENTRIDAE    Chromis
#   151  ACTINOPTERYGII     IUCN      None  POMACENTRIDAE    Chromis
#   152  ACTINOPTERYGII     IUCN      None  POMACENTRIDAE    Chromis
#   153  ACTINOPTERYGII     IUCN      None  POMACENTRIDAE    Chromis
#   154  ACTINOPTERYGII     IUCN      None  POMACENTRIDAE    Chromis
#   155  ACTINOPTERYGII     IUCN      None  POMACENTRIDAE    Chromis
#   156  ACTINOPTERYGII     IUCN      None  POMACENTRIDAE    Chromis
#   157  ACTINOPTERYGII     IUCN      None  POMACENTRIDAE    Chromis
#
#                                                 geometry     id_no  \
#   147  POLYGON ((-121.284812927 35.67465591400003, -1...  183870.0
#   148  POLYGON ((-106.72576642 23.59774532600005, -10...  183870.0
#   149  POLYGON ((-80.59836584099997 -6.38295220699996...  183870.0
#   150  POLYGON ((-86.13105102199995 5.598867493000057...  183870.0
#   151  POLYGON ((-111.159618439 19.01535626700007, -1...  183870.0
#   152  POLYGON ((-108.302926059 10.35825927300004, -1...  183870.0
#   153  POLYGON ((-80.68215272899994 4.037426486000072...  183870.0
#   154  POLYGON ((-90.22271068899994 -0.27334342499995...  183870.0
#   155  POLYGON ((-91.09391784599995 -0.58096068999992...  183870.0
#   156  POLYGON ((-110.946847013 27.91523099000005, -1...  183870.0
#   157  POLYGON ((-91.24864959699994 -0.67984747899993...  183870.0
#
#            ...      phylum_nam rl_update seasonal source  species_na subpop  \
#   147      ...        CHORDATA    2012.1        1   None        alta   None
#   148      ...        CHORDATA    2012.1        1   None        alta   None
#   149      ...        CHORDATA    2012.1        1   None        alta   None
#   150      ...        CHORDATA    2012.1        1   None        alta   None
#   151      ...        CHORDATA    2012.1        1   None        alta   None
#   152      ...        CHORDATA    2012.1        1   None        alta   None
#   153      ...        CHORDATA    2012.1        1   None        alta   None
#   154      ...        CHORDATA    2012.1        1   None        alta   None
#   155      ...        CHORDATA    2012.1        1   None        alta   None
#   156      ...        CHORDATA    2012.1        1   None        alta   None
#   157      ...        CHORDATA    2012.1        1   None        alta   None
#
#        subspecies  tax_comm  year          area
#   147        None      None  2010  3.479862e+01
#   148        None      None  2010  1.700187e+01
#   149        None      None  2010  2.932760e+00
#   150        None      None  2010  2.732157e+00
#   151        None      None  2010  2.697207e+00
#   152        None      None  2010  2.683781e+00
#   153        None      None  2010  2.654657e+00
#   154        None      None  2010  2.381573e+00
#   155        None      None  2010  1.165597e-02
#   156        None      None  2010  2.998990e-05
#   157        None      None  2010  4.885182e-07
#
#   [11 rows x 25 columns]),
#  ('Chromis atrilobata',                binomial category  \
#   204  Chromis atrilobata       LC
#   205  Chromis atrilobata       LC
#   206  Chromis atrilobata       LC
#   207  Chromis atrilobata       LC
#   208  Chromis atrilobata       LC
#   209  Chromis atrilobata       LC
#   210  Chromis atrilobata       LC
#   211  Chromis atrilobata       LC
#   212  Chromis atrilobata       LC
#
#                                                 citation      class_name  \
#   204  International Union for Conservation of Nature...  ACTINOPTERYGII
#   205  International Union for Conservation of Nature...  ACTINOPTERYGII
#   206  International Union for Conservation of Nature...  ACTINOPTERYGII
#   207  International Union for Conservation of Nature...  ACTINOPTERYGII
#   208  International Union for Conservation of Nature...  ACTINOPTERYGII
#   209  International Union for Conservation of Nature...  ACTINOPTERYGII
#   210  International Union for Conservation of Nature...  ACTINOPTERYGII
#   211  International Union for Conservation of Nature...  ACTINOPTERYGII
#   212  International Union for Conservation of Nature...  ACTINOPTERYGII
#
#       compiler dist_comm     family_nam genus_name  \
#   204     IUCN      None  POMACENTRIDAE    Chromis
#   205     IUCN      None  POMACENTRIDAE    Chromis
#   206     IUCN      None  POMACENTRIDAE    Chromis
#   207     IUCN      None  POMACENTRIDAE    Chromis
#   208     IUCN      None  POMACENTRIDAE    Chromis
#   209     IUCN      None  POMACENTRIDAE    Chromis
#   210     IUCN      None  POMACENTRIDAE    Chromis
#   211     IUCN      None  POMACENTRIDAE    Chromis
#   212     IUCN      None  POMACENTRIDAE    Chromis
#
#                                                 geometry     id_no  \
#   204  POLYGON ((-90.09187344499998 13.72481517500006...  183653.0
#   205  POLYGON ((-113.422749196 30.12412492800007, -1...  183653.0
#   206  POLYGON ((-106.72576642 23.59774532600005, -10...  183653.0
#   207  POLYGON ((-86.13105102199995 5.598867493000057...  183653.0
#   208  POLYGON ((-111.159618439 19.01535626700007, -1...  183653.0
#   209  POLYGON ((-80.68215272899994 4.037426486000072...  183653.0
#   210  POLYGON ((-90.22271068899994 -0.27334342499995...  183653.0
#   211  POLYGON ((-91.09391784599995 -0.58096068999992...  183653.0
#   212  POLYGON ((-91.24864959699994 -0.67984747899993...  183653.0
#
#            ...      phylum_nam rl_update seasonal source  species_na subpop  \
#   204      ...        CHORDATA    2012.1        1   None  atrilobata   None
#   205      ...        CHORDATA    2012.1        1   None  atrilobata   None
#   206      ...        CHORDATA    2012.1        1   None  atrilobata   None
#   207      ...        CHORDATA    2012.1        1   None  atrilobata   None
#   208      ...        CHORDATA    2012.1        1   None  atrilobata   None
#   209      ...        CHORDATA    2012.1        1   None  atrilobata   None
#   210      ...        CHORDATA    2012.1        1   None  atrilobata   None
#   211      ...        CHORDATA    2012.1        1   None  atrilobata   None
#   212      ...        CHORDATA    2012.1        1   None  atrilobata   None
#
#        subspecies  tax_comm  year          area
#   204        None      None  2010  3.913388e+01
#   205        None      None  2010  2.588695e+01
#   206        None      None  2010  1.624922e+01
#   207        None      None  2010  2.732157e+00
#   208        None      None  2010  2.697207e+00
#   209        None      None  2010  2.654657e+00
#   210        None      None  2010  2.381573e+00
#   211        None      None  2010  1.165597e-02
#   212        None      None  2010  4.885182e-07
#
#   [9 rows x 25 columns]),
#  ('Chromis crusma',           binomial category  \
#   18  Chromis crusma       LC
#   19  Chromis crusma       LC
#   20  Chromis crusma       LC
#
#                                                citation      class_name  \
#   18  International Union for Conservation of Nature...  ACTINOPTERYGII
#   19  International Union for Conservation of Nature...  ACTINOPTERYGII
#   20  International Union for Conservation of Nature...  ACTINOPTERYGII
#
#      compiler dist_comm     family_nam genus_name  \
#   18     IUCN      None  POMACENTRIDAE    Chromis
#   19     IUCN      None  POMACENTRIDAE    Chromis
#   20     IUCN      None  POMACENTRIDAE    Chromis
#
#                                                geometry     id_no      ...       \
#   18  POLYGON ((-80.82860578399999 -1.22984210599997...  183240.0      ...
#   19  POLYGON ((-67.33922225599997 -55.6761029239999...  183240.0      ...
#   20  POLYGON ((-74.81822204599996 -51.4608230589999...  183240.0      ...
#
#      phylum_nam rl_update seasonal source  species_na subpop  subspecies  \
#   18   CHORDATA    2012.1        1   None      crusma   None        None
#   19   CHORDATA    2012.1        1   None      crusma   None        None
#   20   CHORDATA    2012.1        1   None      crusma   None        None
#
#       tax_comm  year          area
#   18      None  2010  8.724611e+01
#   19      None  2010  9.183696e-04
#   20      None  2010  2.989001e-15
#
#   [3 rows x 25 columns]),
#  ('Chromis cyanea',           binomial category  \
#   50  Chromis cyanea       LC
#   51  Chromis cyanea       LC
#   52  Chromis cyanea       LC
#   53  Chromis cyanea       LC
#   54  Chromis cyanea       LC
#   55  Chromis cyanea       LC
#   56  Chromis cyanea       LC
#   57  Chromis cyanea       LC
#   58  Chromis cyanea       LC
#   59  Chromis cyanea       LC
#   60  Chromis cyanea       LC
#   61  Chromis cyanea       LC
#   62  Chromis cyanea       LC
#   63  Chromis cyanea       LC
#   64  Chromis cyanea       LC
#
#                                                citation      class_name  \
#   50  International Union for Conservation of Nature...  ACTINOPTERYGII
#   51  International Union for Conservation of Nature...  ACTINOPTERYGII
#   52  International Union for Conservation of Nature...  ACTINOPTERYGII
#   53  International Union for Conservation of Nature...  ACTINOPTERYGII
#   54  International Union for Conservation of Nature...  ACTINOPTERYGII
#   55  International Union for Conservation of Nature...  ACTINOPTERYGII
#   56  International Union for Conservation of Nature...  ACTINOPTERYGII
#   57  International Union for Conservation of Nature...  ACTINOPTERYGII
#   58  International Union for Conservation of Nature...  ACTINOPTERYGII
#   59  International Union for Conservation of Nature...  ACTINOPTERYGII
# ...
#   144  POLYGON ((-83.73208617399996 8.582326894000062...  183530.0
#   145  POLYGON ((-91.09391784599995 -0.58096068999992...  183530.0
#   146  POLYGON ((-91.24864959699994 -0.67984747899993...  183530.0
#
#            ...      phylum_nam rl_update seasonal source  species_na subpop  \
#   139      ...        CHORDATA    2012.1        1   None   arcifrons   None
#   140      ...        CHORDATA    2012.1        1   None   arcifrons   None
#   141      ...        CHORDATA    2012.1        1   None   arcifrons   None
#   142      ...        CHORDATA    2012.1        1   None   arcifrons   None
#   143      ...        CHORDATA    2012.1        1   None   arcifrons   None
#   144      ...        CHORDATA    2012.1        1   None   arcifrons   None
#   145      ...        CHORDATA    2012.1        1   None   arcifrons   None
#   146      ...        CHORDATA    2012.1        1   None   arcifrons   None
#
#        subspecies  tax_comm  year          area
#   139        None      None  2010  3.351379e+00
#   140        None      None  2010  2.732157e+00
#   141        None      None  2010  2.654657e+00
#   142        None      None  2010  2.381573e+00
#   143        None      None  2010  1.815833e+00
#   144        None      None  2010  8.060209e-01
#   145        None      None  2010  1.165597e-02
#   146        None      None  2010  4.885182e-07
#
#   [8 rows x 25 columns]),
#  ('Stegastes baldwini',                binomial category  \
#   123  Stegastes baldwini       NT
#
#                                                 citation      class_name  \
#   123  International Union for Conservation of Nature...  ACTINOPTERYGII
#
#       compiler dist_comm     family_nam genus_name  \
#   123     IUCN      None  POMACENTRIDAE  Stegastes
#
#                                                 geometry     id_no    ...     \
#   123  POLYGON ((-108.302926059 10.35825927300004, -1...  183961.0    ...
#
#       phylum_nam rl_update seasonal source  species_na subpop  subspecies  \
#   123   CHORDATA    2012.1        1   None    baldwini   None        None
#
#        tax_comm  year      area
#   123      None  2010  2.683781
#
#   [1 rows x 25 columns]),
#  ('Stegastes beebei',             binomial category  \
#   6   Stegastes beebei       VU
#   7   Stegastes beebei       VU
#   8   Stegastes beebei       VU
#   9   Stegastes beebei       VU
#   10  Stegastes beebei       VU
#   11  Stegastes beebei       VU
#   12  Stegastes beebei       VU
#   13  Stegastes beebei       VU
#
#                                                citation      class_name  \
#   6   International Union for Conservation of Nature...  ACTINOPTERYGII
#   7   International Union for Conservation of Nature...  ACTINOPTERYGII
#   8   International Union for Conservation of Nature...  ACTINOPTERYGII
#   9   International Union for Conservation of Nature...  ACTINOPTERYGII
#   10  International Union for Conservation of Nature...  ACTINOPTERYGII
#   11  International Union for Conservation of Nature...  ACTINOPTERYGII
#   12  International Union for Conservation of Nature...  ACTINOPTERYGII
#   13  International Union for Conservation of Nature...  ACTINOPTERYGII
#
#      compiler dist_comm     family_nam genus_name  \
#   6      IUCN      None  POMACENTRIDAE  Stegastes
#   7      IUCN      None  POMACENTRIDAE  Stegastes
#   8      IUCN      None  POMACENTRIDAE  Stegastes
#   9      IUCN      None  POMACENTRIDAE  Stegastes
#   10     IUCN      None  POMACENTRIDAE  Stegastes
#   11     IUCN      None  POMACENTRIDAE  Stegastes
#   12     IUCN      None  POMACENTRIDAE  Stegastes
#   13     IUCN      None  POMACENTRIDAE  Stegastes
#
#                                                geometry     id_no      ...       \
#   6   POLYGON ((-86.13105102199995 5.598867493000057...  183462.0      ...
#   7   POLYGON ((-80.68215272899994 4.037426486000072...  183462.0      ...
#   8   POLYGON ((-90.22271068899994 -0.27334342499995...  183462.0      ...
#   9   POLYGON ((-83.93571481699996 9.296388679000074...  183462.0      ...
#   10  POLYGON ((-79.15961456299993 9.011326790000055...  183462.0      ...
#   11  POLYGON ((-91.09391784599995 -0.58096068999992...  183462.0      ...
#   12  POLYGON ((-78.46049499599997 8.439051628000072...  183462.0      ...
#   13  POLYGON ((-91.24864959699994 -0.67984747899993...  183462.0      ...
#
#      phylum_nam rl_update seasonal source  species_na subpop  subspecies  \
#   6    CHORDATA    2012.1        1   None      beebei   None        None
#   7    CHORDATA    2012.1        1   None      beebei   None        None
#   8    CHORDATA    2012.1        1   None      beebei   None        None
#   9    CHORDATA    2012.1        1   None      beebei   None        None
#   10   CHORDATA    2012.1        1   None      beebei   None        None
#   11   CHORDATA    2012.1        1   None      beebei   None        None
#   12   CHORDATA    2012.1        1   None      beebei   None        None
#   13   CHORDATA    2012.1        1   None      beebei   None        None
#
#       tax_comm  year          area
#   6       None  2010  2.732157e+00
#   7       None  2010  2.654657e+00
#   8       None  2010  2.381573e+00
#   9       None  2010  5.363015e-01
#   10      None  2010  3.396193e-01
#   11      None  2010  1.165597e-02
#   12      None  2010  1.912753e-04
#   13      None  2010  4.885182e-07
#
#   [8 rows x 25 columns]),
#  ('Stegastes flavilatus',                  binomial category  \
#   175  Stegastes flavilatus       LC
#   176  Stegastes flavilatus       LC
#   177  Stegastes flavilatus       LC
#   178  Stegastes flavilatus       LC
#   179  Stegastes flavilatus       LC
#   180  Stegastes flavilatus       LC
#   181  Stegastes flavilatus       LC
#   182  Stegastes flavilatus       LC
#
#                                                 citation      class_name  \
#   175  International Union for Conservation of Nature...  ACTINOPTERYGII
#   176  International Union for Conservation of Nature...  ACTINOPTERYGII
#   177  International Union for Conservation of Nature...  ACTINOPTERYGII
#   178  International Union for Conservation of Nature...  ACTINOPTERYGII
#   179  International Union for Conservation of Nature...  ACTINOPTERYGII
#   180  International Union for Conservation of Nature...  ACTINOPTERYGII
#   181  International Union for Conservation of Nature...  ACTINOPTERYGII
#   182  International Union for Conservation of Nature...  ACTINOPTERYGII
#
#       compiler dist_comm     family_nam genus_name  \
#   175     IUCN      None  POMACENTRIDAE  Stegastes
#   176     IUCN      None  POMACENTRIDAE  Stegastes
#   177     IUCN      None  POMACENTRIDAE  Stegastes
#   178     IUCN      None  POMACENTRIDAE  Stegastes
#   179     IUCN      None  POMACENTRIDAE  Stegastes
#   180     IUCN      None  POMACENTRIDAE  Stegastes
#   181     IUCN      None  POMACENTRIDAE  Stegastes
#   182     IUCN      None  POMACENTRIDAE  Stegastes
#
#                                                 geometry     id_no  \
#   175  POLYGON ((-90.09187344499998 13.72481517500006...  183747.0
#   176  POLYGON ((-111.7060852279999 28.46735767100006...  183747.0
#   177  POLYGON ((-106.726318976 23.59928014100007, -1...  183747.0
#   178  POLYGON ((-86.13105102199995 5.598867493000057...  183747.0
#   179  POLYGON ((-111.159618439 19.01535626700007, -1...  183747.0
#   180  POLYGON ((-90.22271068899994 -0.27334342499995...  183747.0
#   181  POLYGON ((-91.09391784599995 -0.58096068999992...  183747.0
#   182  POLYGON ((-91.24864959699994 -0.67984747899993...  183747.0
#
#            ...      phylum_nam rl_update seasonal source  species_na subpop  \
#   175      ...        CHORDATA    2012.1        1   None  flavilatus   None
#   176      ...        CHORDATA    2012.1        1   None  flavilatus   None
#   177      ...        CHORDATA    2012.1        1   None  flavilatus   None
#   178      ...        CHORDATA    2012.1        1   None  flavilatus   None
#   179      ...        CHORDATA    2012.1        1   None  flavilatus   None
#   180      ...        CHORDATA    2012.1        1   None  flavilatus   None
#   181      ...        CHORDATA    2012.1        1   None  flavilatus   None
#   182      ...        CHORDATA    2012.1        1   None  flavilatus   None
#
#        subspecies  tax_comm  year          area
#   175        None      None  2010  3.913388e+01
#   176        None      None  2010  1.818651e+01
#   177        None      None  2010  1.700187e+01
#   178        None      None  2010  2.732157e+00
#   179        None      None  2010  2.697207e+00
#   180        None      None  2010  2.381573e+00
#   181        None      None  2010  1.165597e-02
#   182        None      None  2010  4.885182e-07
#
#   [8 rows x 25 columns]),
#  ('Stegastes leucorus',              binomial category  \
#   0  Stegastes leucorus       VU
#   1  Stegastes leucorus       VU
#   2  Stegastes leucorus       VU
#
#                                               citation      class_name compiler  \
#   0  International Union for Conservation of Nature...  ACTINOPTERYGII     IUCN
#   1  International Union for Conservation of Nature...  ACTINOPTERYGII     IUCN
#   2  International Union for Conservation of Nature...  ACTINOPTERYGII     IUCN
#
#     dist_comm     family_nam genus_name  \
#   0      None  POMACENTRIDAE  Stegastes
#   1      None  POMACENTRIDAE  Stegastes
#   2      None  POMACENTRIDAE  Stegastes
#
#                                               geometry     id_no    ...      \
#   0  POLYGON ((-115.6437454219999 29.71392059300007...  183963.0    ...
#   1  POLYGON ((-105.589950704 21.89339825500002, -1...  183963.0    ...
#   2  POLYGON ((-111.159618439 19.01535626700007, -1...  183963.0    ...
#
#     phylum_nam rl_update seasonal source  species_na subpop  subspecies  \
#   0   CHORDATA    2012.1        1   None    leucorus   None        None
#   1   CHORDATA    2012.1        1   None    leucorus   None        None
#   2   CHORDATA    2012.1        1   None    leucorus   None        None
#
#      tax_comm  year       area
#   0      None  2010  19.396254
#   1      None  2010   6.145902
#   2      None  2010   2.697207
#
#   [3 rows x 25 columns]),
#  ('Stegastes rectifraenum',                   binomial category  \
#   14  Stegastes rectifraenum       LC
#   15  Stegastes rectifraenum       LC
#   16  Stegastes rectifraenum       LC
#
#                                                citation      class_name  \
#   14  International Union for Conservation of Nature...  ACTINOPTERYGII
#   15  International Union for Conservation of Nature...  ACTINOPTERYGII
#   16  International Union for Conservation of Nature...  ACTINOPTERYGII
#
#      compiler dist_comm     family_nam genus_name  \
#   14     IUCN      None  POMACENTRIDAE  Stegastes
#   15     IUCN      None  POMACENTRIDAE  Stegastes
#   16     IUCN      None  POMACENTRIDAE  Stegastes
#
#                                                geometry     id_no    ...      \
#   14  POLYGON ((-114.129066467 31.49156189000007, -1...  183586.0    ...
#   15  POLYGON ((-106.7327677389999 23.60688894500004...  183586.0    ...
#   16  POLYGON ((-111.159618439 19.01535626700007, -1...  183586.0    ...
#
#      phylum_nam rl_update seasonal source    species_na subpop  subspecies  \
#   14   CHORDATA    2012.1        1   None  rectifraenum   None        None
#   15   CHORDATA    2012.1        1   None  rectifraenum   None        None
#   16   CHORDATA    2012.1        1   None  rectifraenum   None        None
#
#       tax_comm  year       area
#   14      None  2010  27.347730
#   15      None  2010  10.479282
#   16      None  2010   2.697207
#
#   [3 rows x 25 columns]),
#  ('Stegastes redemptus',                binomial category  \
#   25  Stegastes redemptus       VU
#   26  Stegastes redemptus       VU
#
#                                                citation      class_name  \
#   25  International Union for Conservation of Nature...  ACTINOPTERYGII
#   26  International Union for Conservation of Nature...  ACTINOPTERYGII
#
#      compiler dist_comm     family_nam genus_name  \
#   25     IUCN      None  POMACENTRIDAE  Stegastes
#   26     IUCN      None  POMACENTRIDAE  Stegastes
#
#                                                geometry     id_no    ...     \
#   25  POLYGON ((-112.128707413 25.07043759500004, -1...  183567.0    ...
#   26  POLYGON ((-111.159618439 19.01535626700007, -1...  183567.0    ...
#
#      phylum_nam rl_update seasonal source  species_na subpop  subspecies  \
#   25   CHORDATA    2012.1        1   None   redemptus   None        None
#   26   CHORDATA    2012.1        1   None   redemptus   None        None
#
#       tax_comm  year      area
#   25      None  2010  4.810736
#   26      None  2010  2.697207
#
#   [2 rows x 25 columns]),
#  ('Teixeirichthys jordani',                   binomial category  \
#   27  Teixeirichthys jordani       LC
#   28  Teixeirichthys jordani       LC
#   29  Teixeirichthys jordani       LC
#   30  Teixeirichthys jordani       LC
#   31  Teixeirichthys jordani       LC
#   32  Teixeirichthys jordani       LC
#   33  Teixeirichthys jordani       LC
#
#                                                citation      class_name  \
#   27  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
#   28  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
#   29  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
#   30  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
#   31  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
#   32  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
#   33  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
#
#      compiler dist_comm     family_nam      genus_name  \
#   27     None      None  POMACENTRIDAE  Teixeirichthys
#   28     None      None  POMACENTRIDAE  Teixeirichthys
#   29     None      None  POMACENTRIDAE  Teixeirichthys
#   30     None      None  POMACENTRIDAE  Teixeirichthys
#   31     None      None  POMACENTRIDAE  Teixeirichthys
#   32     None      None  POMACENTRIDAE  Teixeirichthys
#   33     None      None  POMACENTRIDAE  Teixeirichthys
#
#                                                geometry     id_no    ...      \
#   27  POLYGON ((121.6300326400001 33.04248618400004,...  154915.0    ...
#   28  POLYGON ((32.56219482400007 29.97488975500005,...  154915.0    ...
#   29  POLYGON ((130.9052090560001 34.02498196400006,...  154915.0    ...
#   30  POLYGON ((56.32233070000007 -3.707270205999976...  154915.0    ...
#   31  POLYGON ((40.64476131800006 -10.85502363999996...  154915.0    ...
#   32  POLYGON ((48.11258402900006 -9.335103113999935...  154915.0    ...
#   33  POLYGON ((51.75403543100003 -9.21679305899994,...  154915.0    ...
#
#      phylum_nam rl_update seasonal source  species_na subpop  subspecies  \
#   27   CHORDATA    2012.2        1   None     jordani   None        None
#   28   CHORDATA    2012.2        1   None     jordani   None        None
#   29   CHORDATA    2012.2        1   None     jordani   None        None
#   30   CHORDATA    2012.2        1   None     jordani   None        None
#   31   CHORDATA    2012.2        1   None     jordani   None        None
#   32   CHORDATA    2012.2        1   None     jordani   None        None
#   33   CHORDATA    2012.2        1   None     jordani   None        None
#
#       tax_comm  year       area
#   27      None  2012  38.671198
#   28      None  2012  37.445735
#   29      None  2012  16.939460
#   30      None  2012  10.126967
#   31      None  2012   7.760303
#   32      None  2012   3.434236
#   33      None  2012   2.408620
#
#   [7 rows x 25 columns])]

# %%
# Iterate over the group object
for key, values in grouped:
    individual_fish = values

# Let's see what is the LAST item that we iterated
individual_fish
# Out:
#                   binomial category  \
# 27  Teixeirichthys jordani       LC
# 28  Teixeirichthys jordani       LC
# 29  Teixeirichthys jordani       LC
# 30  Teixeirichthys jordani       LC
# 31  Teixeirichthys jordani       LC
# 32  Teixeirichthys jordani       LC
# 33  Teixeirichthys jordani       LC
#
#                                              citation      class_name  \
# 27  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
# 28  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
# 29  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
# 30  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
# 31  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
# 32  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
# 33  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
#
#    compiler dist_comm     family_nam      genus_name  \
# 27     None      None  POMACENTRIDAE  Teixeirichthys
# 28     None      None  POMACENTRIDAE  Teixeirichthys
# 29     None      None  POMACENTRIDAE  Teixeirichthys
# 30     None      None  POMACENTRIDAE  Teixeirichthys
# 31     None      None  POMACENTRIDAE  Teixeirichthys
# 32     None      None  POMACENTRIDAE  Teixeirichthys
# 33     None      None  POMACENTRIDAE  Teixeirichthys
#
#                                              geometry     id_no    ...      \
# 27  POLYGON ((121.6300326400001 33.04248618400004,...  154915.0    ...
# 28  POLYGON ((32.56219482400007 29.97488975500005,...  154915.0    ...
# 29  POLYGON ((130.9052090560001 34.02498196400006,...  154915.0    ...
# 30  POLYGON ((56.32233070000007 -3.707270205999976...  154915.0    ...
# 31  POLYGON ((40.64476131800006 -10.85502363999996...  154915.0    ...
# 32  POLYGON ((48.11258402900006 -9.335103113999935...  154915.0    ...
# 33  POLYGON ((51.75403543100003 -9.21679305899994,...  154915.0    ...
#
#    phylum_nam rl_update seasonal source  species_na subpop  subspecies  \
# 27   CHORDATA    2012.2        1   None     jordani   None        None
# 28   CHORDATA    2012.2        1   None     jordani   None        None
# 29   CHORDATA    2012.2        1   None     jordani   None        None
# 30   CHORDATA    2012.2        1   None     jordani   None        None
# 31   CHORDATA    2012.2        1   None     jordani   None        None
# 32   CHORDATA    2012.2        1   None     jordani   None        None
# 33   CHORDATA    2012.2        1   None     jordani   None        None
#
#     tax_comm  year       area
# 27      None  2012  38.671198
# 28      None  2012  37.445735
# 29      None  2012  16.939460
# 30      None  2012  10.126967
# 31      None  2012   7.760303
# 32      None  2012   3.434236
# 33      None  2012   2.408620
#
# [7 rows x 25 columns]

# %%
type(individual_fish)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
print(key)
# Out:
# Teixeirichthys jordani

# %%
#Same selection by get_group() method
grouped.get_group('Teixeirichthys jordani')
# Out:
#                   binomial category  \
# 27  Teixeirichthys jordani       LC
# 28  Teixeirichthys jordani       LC
# 29  Teixeirichthys jordani       LC
# 30  Teixeirichthys jordani       LC
# 31  Teixeirichthys jordani       LC
# 32  Teixeirichthys jordani       LC
# 33  Teixeirichthys jordani       LC
#
#                                              citation      class_name  \
# 27  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
# 28  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
# 29  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
# 30  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
# 31  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
# 32  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
# 33  Red List Index (Sampled Approach), Zoological ...  ACTINOPTERYGII
#
#    compiler dist_comm     family_nam      genus_name  \
# 27     None      None  POMACENTRIDAE  Teixeirichthys
# 28     None      None  POMACENTRIDAE  Teixeirichthys
# 29     None      None  POMACENTRIDAE  Teixeirichthys
# 30     None      None  POMACENTRIDAE  Teixeirichthys
# 31     None      None  POMACENTRIDAE  Teixeirichthys
# 32     None      None  POMACENTRIDAE  Teixeirichthys
# 33     None      None  POMACENTRIDAE  Teixeirichthys
#
#                                              geometry     id_no    ...      \
# 27  POLYGON ((121.6300326400001 33.04248618400004,...  154915.0    ...
# 28  POLYGON ((32.56219482400007 29.97488975500005,...  154915.0    ...
# 29  POLYGON ((130.9052090560001 34.02498196400006,...  154915.0    ...
# 30  POLYGON ((56.32233070000007 -3.707270205999976...  154915.0    ...
# 31  POLYGON ((40.64476131800006 -10.85502363999996...  154915.0    ...
# 32  POLYGON ((48.11258402900006 -9.335103113999935...  154915.0    ...
# 33  POLYGON ((51.75403543100003 -9.21679305899994,...  154915.0    ...
#
#    phylum_nam rl_update seasonal source  species_na subpop  subspecies  \
# 27   CHORDATA    2012.2        1   None     jordani   None        None
# 28   CHORDATA    2012.2        1   None     jordani   None        None
# 29   CHORDATA    2012.2        1   None     jordani   None        None
# 30   CHORDATA    2012.2        1   None     jordani   None        None
# 31   CHORDATA    2012.2        1   None     jordani   None        None
# 32   CHORDATA    2012.2        1   None     jordani   None        None
# 33   CHORDATA    2012.2        1   None     jordani   None        None
#
#     tax_comm  year       area
# 27      None  2012  38.671198
# 28      None  2012  37.445735
# 29      None  2012  16.939460
# 30      None  2012  10.126967
# 31      None  2012   7.760303
# 32      None  2012   3.434236
# 33      None  2012   2.408620
#
# [7 rows x 25 columns]

# %% [markdown]
# As can be seen from the example above, each set of data are now grouped into separate GeoDataFrames that we can export into Shapefiles using the variable `key` for creating the output filepath names. Let’s now export those species into individual Shapefiles.

# %%
import os
# Determine outputpath
outFolder = r"Output/"

# Create a new folder called 'Results' (if does not exist) to that 
# folder using os.makedirs() function
resultFolder = os.path.join(outFolder, 'Results')
if not os.path.exists(resultFolder):
    os.makedirs(resultFolder)

# Iterate over the
for key, values in grouped:
    # Format the filename (replace spaces with underscores)
    outName = "%s.shp" % key.replace(" ", "_")

    # Print some information for the user
    print("Processing: %s" % key)

    # Create an output path
    outpath = os.path.join(resultFolder, outName)

    # Export the data
    values.to_file(outpath)
# Out:
# Processing: Abudefduf concolor
# Processing: Abudefduf declivifrons
# Processing: Abudefduf troschelii
# Processing: Amphiprion sandaracinos
# Processing: Azurina eupalama
# Processing: Azurina hirundo
# Processing: Chromis alpha
# Processing: Chromis alta
# Processing: Chromis atrilobata
# Processing: Chromis crusma
# Processing: Chromis cyanea
# Processing: Chromis flavicauda
# Processing: Chromis intercrusma
# Processing: Chromis limbaughi
# Processing: Chromis pembae
# Processing: Chromis punctipinnis
# Processing: Chrysiptera flavipinnis
# Processing: Hypsypops rubicundus
# Processing: Microspathodon bairdii
# Processing: Microspathodon dorsalis
# Processing: Nexilosus latifrons
# Processing: Stegastes acapulcoensis
# Processing: Stegastes arcifrons
# Processing: Stegastes baldwini
# Processing: Stegastes beebei
# Processing: Stegastes flavilatus
# Processing: Stegastes leucorus
# Processing: Stegastes rectifraenum
# Processing: Stegastes redemptus
# Processing: Teixeirichthys jordani
